# %% [markdown]
# ---
# **© 2026 Abhishek Kushwaha. All Rights Reserved.**
#
# This notebook is for personal learning/portfolio purposes.
# Do not copy, distribute, or reuse without permission.
#
# ---

# %% [markdown]
# # Introduction to Pandas
#
# In this section of the course we will learn how to use pandas for data analysis. You can think of pandas as an extremely powerful version of Excel, with a lot more features. In this section of the course, you should go through the notebooks in this order:
#
# * Introduction to Pandas
# * Series
# * DataFrames
# * Missing Data
# * GroupBy
# * Merging,Joining,and Concatenating
# * Operations
# * Data Input and Output

# %% [markdown]
# # Great Job!

# %% [markdown]
# <p style="font-size:9px; color:#999;">Notes by Abhishek kushwaha | https://github.com/theabhikushwaha | © 2026</p>
